# %%
import pandas as pd
from data_processing import DataProcessor
from model_rf import RandomForestModel

# Load and process data
file_path = 'encoded_crop_recommendations.csv'
df = pd.read_csv(file_path)

def select_model(nitrogen, phosphorus, potassium, soil, crop, temperature=None):
  # Extract rows matching the selected crop
  crop_data = df[df['Crop'] == crop]

  # Determine number of available rows
  row_count = len(crop_data)

  if row_count >= 200:
      print(f"Using Neural Network Model (Rows: {row_count})")
      model = NeuralNetworkModel()
      if not model.trained: 
        model.train(crop_data)
  elif 50 <= row_count < 200:
      print(f"Using Random Forest Model (Rows: {row_count})")
      model = RandomForestModel()
      if not model.trained:
        model.train(crop_data)
  else:
      print(f"Using Rule-Based System (Rows: {row_count})")
      model = RuleBasedModel()
      if not model.trained:
        model.train(crop_data)

  soil_encoded, crop_encoded = data_processor.encode_input(soil, crop)

  # **Get prediction from the trained model**
  fertilizer, recommendation = model.predict(nitrogen, phosphorus, potassium, soil_encoded, crop_encoded, temperature)

  return fertilizer, recommendation

# Example usage
fertilizer, recommendation = select_model(80, 40, 120, "Red", "grapes", 20)
print("\nPredicted Fertilizer:", fertilizer)
print("Predicted Recommendation:\n", recommendation)
# Out:
# Using Random Forest Model (Rows: 125)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15564\3731910864.py in ?()
#      36
#      37   return fertilizer, recommendation
#      38
#      39 # Example usage
# ---> 40 fertilizer, recommendation = select_model(80, 40, 120, "Red", "grapes", 20)
#      41 print("\nPredicted Fertilizer:", fertilizer)
#      42 print("Predicted Recommendation:\n", recommendation)
#
# ~\AppData\Local\Temp\ipykernel_15564\3731910864.py in ?(nitrogen, phosphorus, potassium, soil, crop, temperature)
#      21   elif 50 <= row_count < 200:
#      22       print(f"Using Random Forest Model (Rows: {row_count})")
#      23       model = RandomForestModel()
#      24       if not model.trained:
# ---> 25         model.train(crop_data)
#      26   else:
#      27       print(f"Using Rule-Based System (Rows: {row_count})")
# ...
